# %%
import pandas as pd 
import os

# %% [markdown]
# #### merging 12 months sales

# %%
df = pd.read_csv('./Sales_Data/Sales_April_2019.csv')
files = [file for file in os.listdir('./Sales_Data')]

all_data = pd.DataFrame()

for file in files:
    df = pd.read_csv('./Sales_Data/'+file)
    all_data = pd.concat([all_data,df])
    
all_data.to_csv('all_data.csv',index=False)

# %% [markdown]
# ###### Read the file from CSV

# %%
all_sales = pd.read_csv('all_data.csv')
all_sales
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1           NaN                         NaN              NaN        NaN
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
all_sales.describe()
# Out:
#         Order ID               Product Quantity Ordered Price Each  \
# count     186305                186305           186305     186305
# unique    178438                    20               10         24
# top     Order ID  USB-C Charging Cable                1      11.95
# freq         355                 21903           168552      21903
#
#         Order Date  Purchase Address
# count       186305            186305
# unique      142396            140788
# top     Order Date  Purchase Address
# freq           355               355

# %%
all_sales.isnull().sum()
# Out:
# Order ID            545
# Product             545
# Quantity Ordered    545
# Price Each          545
# Order Date          545
# Purchase Address    545
# dtype: int64

# %%
all_sales.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# dtype: object

# %% [markdown]
# #### clean up the data

# %%
all_sales = all_sales.dropna(how = 'all')

# %%
all_sales.isnull().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %%
# rename the df for quick access

# %%
df = all_sales
df.isnull().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %%
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %% [markdown]
# ### add month column

# %%
df['month'] = df['Order Date'].str[0:2]
df.head()
# Out:
# C:\Users\Mahdi\AppData\Local\Temp\ipykernel_14212\3310949889.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month'] = df['Order Date'].str[0:2]
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address month
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001    04
# ...

# %%
# find the Or in the error 
df = df[df['Order Date'].str[0:2] != 'Or' ]

# %%
#ignore the warnings
import warnings
warnings.filterwarnings('ignore')

# %%
df['month'] = df['month'].astype('int')
df['month'].dtype
# Out:
# dtype('int32')

# %%
# convert column to the correct type 
df['Quantity Ordered'] = pd.to_numeric(df['Quantity Ordered'])
df['Price Each'] = pd.to_numeric(df['Price Each'])

# %%
df['sales'] = df['Quantity Ordered'] * df['Price Each']
df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3        2.99
# 186846   259354                      iPhone                 1      700.00
# 186847   259355                      iPhone                 1      700.00
# 186848   259356      34in Ultrawide Monitor                 1      379.99
# 186849   259357        USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  month   sales
# ...

# %%
result = df.groupby('month').sum()
result
# Out:
#        Quantity Ordered  Price Each       sales
# month
# 1                 10903  1811768.38  1822256.73
# 2                 13449  2188884.72  2202022.42
# 3                 17005  2791207.83  2807100.38
# 4                 20558  3367671.02  3390670.24
# 5                 18667  3135125.13  3152606.75
# 6                 15253  2562025.61  2577802.26
# 7                 16072  2632539.56  2647775.76
# 8                 13448  2230345.42  2244467.88
# 9                 13109  2084992.09  2097560.13
# 10                22703  3715554.83  3736726.88
# 11                19798  3180600.68  3199603.20
# 12                28114  4588415.41  4613443.34

# %%
import matplotlib.pyplot as plt

# %%
plt.ticklabel_format(style='plain')
months = range(1,13)
plt.title('month sales')
plt.xticks(months)
plt.xlabel('months')
plt.ylabel('sales ($)')
plt.plot(months,result['sales'])
plt.show()

# %% [markdown]
# ### What city has the most sales ?

# %%
temp_city = df['Purchase Address'].str.split(',')
city = temp_city.str[1]
df['city'] = city
df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3        2.99
# 186846   259354                      iPhone                 1      700.00
# 186847   259355                      iPhone                 1      700.00
# 186848   259356      34in Ultrawide Monitor                 1      379.99
# 186849   259357        USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  month  \
# ...

# %%
result_city = df.groupby('city').sum()
result_city
# Out:
#                 Quantity Ordered  Price Each   month       sales
# city
#  Atlanta                   16602  2779908.20  104794  2795498.58
#  Austin                    11153  1809873.61   69829  1819581.75
#  Boston                    22528  3637409.77  141112  3661642.01
#  Dallas                    16730  2752627.82  104620  2767975.40
#  Los Angeles               33289  5421435.23  208325  5452570.80
#  New York City             27932  4635370.83  175741  4664317.43
#  Portland                  14053  2307747.47   87765  2320490.61
#  San Francisco             50239  8211461.74  315520  8262203.91
#  Seattle                   16553  2733296.01  104941  2747755.48

# %%
cities = [city for city , all_data in df.groupby('city')]
cities
# Out:
# [' Atlanta',
#  ' Austin',
#  ' Boston',
#  ' Dallas',
#  ' Los Angeles',
#  ' New York City',
#  ' Portland',
#  ' San Francisco',
#  ' Seattle']

# %%
plt.title('sales per city')
plt.bar(cities,result_city['sales'])
plt.xlabel('cities')
plt.ylabel('sales ($)')
plt.xticks(cities,rotation = 'vertical')
plt.show()

# %% [markdown]
# ### what is the best time to display advertisements to maximize the liklihood of customer's buying product ?

# %%
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  month   sales  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4   23.90
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4   99.99
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4   11.99
#
#            city
# 0        Dallas
# 2        Boston
# 3   Los Angeles
# 4   Los Angeles
# 5   Los Angeles

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
df['Hour'] = df['Order Date'].dt.hour
df['Count'] = 1
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  month   sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#            city  Hour  Count
# 0        Dallas     8      1
# 2        Boston    22      1
# ...

# %%
hour_result = df.groupby(['Hour']).count()
hour_result
# Out:
#       Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# Hour
# 0         3910     3910              3910        3910        3910
# 1         2350     2350              2350        2350        2350
# 2         1243     1243              1243        1243        1243
# 3          831      831               831         831         831
# 4          854      854               854         854         854
# 5         1321     1321              1321        1321        1321
# 6         2482     2482              2482        2482        2482
# 7         4011     4011              4011        4011        4011
# 8         6256     6256              6256        6256        6256
# 9         8748     8748              8748        8748        8748
# 10       10944    10944             10944       10944       10944
# 11       12411    12411             12411       12411       12411
# 12       12587    12587             12587       12587       12587
# ...

# %%
hours = [hour for hour , all_data in df.groupby('Hour')]
plt.figure(figsize=(10,6))
plt.plot(hours,hour_result['Count'])
plt.xticks(hours)
plt.xlabel('Hour')
plt.ylabel('Number of Orders')
plt.grid()
plt.show()

# %% [raw]
# -------------             Around 11h -> 12h and at 19h is the best times to display ADS                   ----------------------

# %% [markdown]
# #### Analysis of the products

# %%
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  month   sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#            city  Hour  Count
# 0        Dallas     8      1
# 2        Boston    22      1
# ...

# %%
number_pro = len(df['Product'].unique())
print("there are ",number_pro,"different products")
# Out:
# there are  19 different products

# %%
products = [product for product , all_data in df.groupby('Product')]
products
# Out:
# ['20in Monitor',
#  '27in 4K Gaming Monitor',
#  '27in FHD Monitor',
#  '34in Ultrawide Monitor',
#  'AA Batteries (4-pack)',
#  'AAA Batteries (4-pack)',
#  'Apple Airpods Headphones',
#  'Bose SoundSport Headphones',
#  'Flatscreen TV',
#  'Google Phone',
#  'LG Dryer',
#  'LG Washing Machine',
#  'Lightning Charging Cable',
#  'Macbook Pro Laptop',
#  'ThinkPad Laptop',
#  'USB-C Charging Cable',
#  'Vareebadd Phone',
#  'Wired Headphones',
#  'iPhone']

# %%
result_products = df.groupby('Product').sum()
result_products
# result_products = result_products.sort_values(by = ['sales'])
#when i sort by sales the visual display wrong values !
# Out:
#                             Quantity Ordered  Price Each   month       sales  \
# Product
# 20in Monitor                            4129   451068.99   29336   454148.71
# 27in 4K Gaming Monitor                  6244  2429637.70   44440  2435097.56
# 27in FHD Monitor                        7550  1125974.93   52558  1132424.50
# 34in Ultrawide Monitor                  6199  2348718.19   43304  2355558.01
# AA Batteries (4-pack)                  27635    79015.68  145558   106118.40
# AAA Batteries (4-pack)                 31017    61716.59  146370    92740.83
# Apple Airpods Headphones               15661  2332350.00  109477  2349150.00
# Bose SoundSport Headphones             13457  1332366.75   94113  1345565.43
# Flatscreen TV                           4819  1440000.00   34224  1445700.00
# Google Phone                            5532  3315000.00   38305  3319200.00
# LG Dryer                                 646   387600.00    4383   387600.00
# ...

# %%
plt.figure(figsize=(12,6))
plt.ticklabel_format(style='plain')
plt.barh(products,result_products['sales'],zorder = 3)
plt.grid(True,zorder = -1)
plt.xlabel('sales')
plt.ylabel('products')
plt.title('sales per product')
plt.show()

# %%
product_group = df.groupby('Product')
quantity_ord = product_group.sum()['Quantity Ordered']
plt.bar(products,quantity_ord)
plt.xticks(products,rotation = 'vertical' )
plt.title('Quantity Ordered of each product')
plt.ylabel('Quantity Ordered')
plt.show()

# %% [markdown]
# #### What Products are most likely sold together ?

# %%
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  month   sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#            city  Hour  Count
# 0        Dallas     8      1
# 2        Boston    22      1
# ...

# %%
# finding the duplicated orders in the dataframe 

duplic = df[df['Order ID'].duplicated(keep = False)]
duplic
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 18       176574                Google Phone                 1      600.00
# 19       176574        USB-C Charging Cable                 1       11.95
# 30       176585  Bose SoundSport Headphones                 1       99.99
# ...         ...                         ...               ...         ...
# 186792   259303       AA Batteries (4-pack)                 1        3.84
# 186803   259314            Wired Headphones                 1       11.99
# 186804   259314      AAA Batteries (4-pack)                 2        2.99
# 186841   259350                Google Phone                 1      600.00
# 186842   259350        USB-C Charging Cable                 1       11.95
#
#                 Order Date                       Purchase Address  month  \
# ...

# %%
duplic['group'] = duplic.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
duplic.head(15)
# Out:
#     Order ID                     Product  Quantity Ordered  Price Each  \
# 3     176560                Google Phone                 1      600.00
# 4     176560            Wired Headphones                 1       11.99
# 18    176574                Google Phone                 1      600.00
# 19    176574        USB-C Charging Cable                 1       11.95
# 30    176585  Bose SoundSport Headphones                 1       99.99
# 31    176585  Bose SoundSport Headphones                 1       99.99
# 32    176586      AAA Batteries (4-pack)                 2        2.99
# 33    176586                Google Phone                 1      600.00
# 119   176672    Lightning Charging Cable                 1       14.95
# 120   176672        USB-C Charging Cable                 1       11.95
# 129   176681    Apple Airpods Headphones                 1      150.00
# 130   176681             ThinkPad Laptop                 1      999.99
# ...

# %%
duplic = duplic[['Order ID','group']].drop_duplicates()
duplic.head()
# Out:
#     Order ID                                              group
# 3     176560                      Google Phone,Wired Headphones
# 18    176574                  Google Phone,USB-C Charging Cable
# 30    176585  Bose SoundSport Headphones,Bose SoundSport Hea...
# 32    176586                AAA Batteries (4-pack),Google Phone
# 119   176672      Lightning Charging Cable,USB-C Charging Cable

# %%
values =  duplic['group'].value_counts()
values.sort_values(ascending=False)
values.head(20)
# Out:
# iPhone,Lightning Charging Cable                       882
# Google Phone,USB-C Charging Cable                     856
# iPhone,Wired Headphones                               361
# Vareebadd Phone,USB-C Charging Cable                  312
# Google Phone,Wired Headphones                         303
# iPhone,Apple Airpods Headphones                       286
# Google Phone,Bose SoundSport Headphones               161
# Vareebadd Phone,Wired Headphones                      104
# Google Phone,USB-C Charging Cable,Wired Headphones     77
# Vareebadd Phone,Bose SoundSport Headphones             60
# iPhone,Lightning Charging Cable,Wired Headphones       56
# Lightning Charging Cable,USB-C Charging Cable          55
# Lightning Charging Cable,AA Batteries (4-pack)         52
# Lightning Charging Cable,Lightning Charging Cable      51
# AA Batteries (4-pack),Lightning Charging Cable         51
# AAA Batteries (4-pack),USB-C Charging Cable            50
# ...
